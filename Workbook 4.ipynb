# %%
from cs103 import *

# %% [markdown]
# ## Task 1
#
# Design a function that takes three numbers as arguments, `a`, `b`, `c`.
# The function is to add `a`, `b`, `c` together and then divide that value by `3`. It will return a `float`.
#
# Call this function `mean_3`.
#
# * Start with the **stub** by writing the signature and the doc string
# * Follow this by writing three tests of expected outputs for expected inputs
# * Last, write the implementation of the function and make sure your tests pass

# %% [markdown]
# **Stub/Function:**

# %%
def mean_3(...) -> ...: # To get you started
    pass

# %% [markdown]
# **Tests:**

# %%
start_testing() # Fill in your tests, here
expect(mean_3(), ...)
expect(mean_3(), ...)
expect(mean_3(), ...)
summary()

# %% [markdown]
# ### Reviewer comments

# %% [markdown]
# ## Task 2
#
# Design a function called `loud` that takes two arguments, a `str` and an `int`. The function is to return the string in all caps with exclamation marks at the end. The number of exclamation marks is to be equal to the value of the `int` argument.
#
# Be sure to follow the same process as in Task 1 for this and all of the following tasks: first write the stub, then your tests, then write the implementation.

# %% [markdown]
# **Stub/Function:**

# %% [markdown]
# **Tests:**

# %% [markdown]
# ### Reviewer comments

# %% [markdown]
# ## Task 3
#
# Design a function called `rjc_email_address` that takes two parameters, `first_name` and `last_name`, which could be any combination of upper or lower case characters. The function will return a `str` which will be that person's RJC email address which is to be entirely lower case.

# %% [markdown]
# **Stub/Function:**

# %% [markdown]
# **Tests:**

# %% [markdown]
# ### Reviewer comments

# %% [markdown]
# ## Task 4
#
# Design a function called `ring_area` that takes two `float` as arguments. These arguments represent the outer and inner diameter of two rings:
#
# ![image.png](attachment:image.png)
#
# The function will return a `float` which represents the area of the ring. If you do not remember the formula for the area of a circle, it is $A = \pi d^2 / 4$.
#
# To write tests for this function, you will need to perform separate calculations on a calculator.

# %% [markdown]
# **Stub/Function:**

# %% [markdown]
# **Tests:**

# %% [markdown]
# ### Reviewer Comments

# %% [markdown]
# ## Task 5
#
# Design a function called `distance` that takes two 2-element tuples as arguments. The tuples represent `(x, y)` coordinates in 2D space, e.g. `(3, 4)` and `(10, 0.25)` could be two valid arguments.
#
# The function will return a `float`, which will represent the distance between the two points (specifically referred to as the [Euclidean distance](https://en.wikipedia.org/wiki/Euclidean_distance)).
#
# To write tests, you will have to know the result of the calculation in advance. To make this easier, use coordinates where you can calculate the distance in your head easily (such as vertical or horizontal lines). You can also [use this list of Pythogorean triples](https://en.wikipedia.org/wiki/Pythagorean_triple).
#
# A Pythagorean triple can be represented as a right-triangle whose lengths of each side are whole numbers (i.e. `int`s). A well known Pythagorean triple is 3, 4, 5.
#
# ![image.png](attachment:image.png)
#
# In this case, you might choose your first coordinate to be `(0, 0)` and your second coordinate to be `(3, 4)`. The result should be `5`.

# %% [markdown]
# **Stub/Function:**

# %% [markdown]
# **Tests:**

# %% [markdown]
# ### Reviewer comments

# %% [markdown]
# ## Task 6
#
# Design a function called `perimeter_triangle` that takes one argument, a `list` of three `tuple`s. Each tuple, as in **Task 5**, will represent a point in 2D space as an `(x, y)` coordinate. The list of three tuples represents the three points of a triangle in 2D space.
#
# Example of possible input:
# ```python
# [(0, 0), (-1, 5), (10, 2)]
# ```
#
# The function will return a `float` representing the perimeter of the triangle.
#
# The intention behind this task is for you to use the function `distance` from **Task 5** in the implementation of `perimeter_triangle`. You do not need to copy and paste the code from Task 5 into this function. Because you have already defined `distance` in a previous cell, just call the function wherever you might need to within the implementation of `perimeter_triangle`.
#
# When writing tests, [use the list of Pythogorean triples](https://en.wikipedia.org/wiki/Pythagorean_triple). For example, in the 3, 4, 5 triangle you know that the lengths of each side so it is easy to write the test now. Your inputs for the 3, 4, 5 triangle might look like, `(0, 0), (0, 3), (3, 4)`.

# %% [markdown]
# **Stub/Function:**

# %% [markdown]
# **Tests:**

# %% [markdown]
# ### Reviewer comments
